# %%
from sklearn.cluster import KMeans
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = {
    "Nama": ["Aida", "Arief", "Adi", "Jasmine", "Laela", "Firdaus", "Insan", "Husni", "Faqih", "Dwi", "Rizki", "Efendi", "Zaky", "Linda"],
    "Tekanan_Darah": [129,115,122,142,148,143,108,138,107,104,148,147,137,120],
    "Berat_Badan": [60,58,57,80,75,78,50,70,51,45,90,88,71,55]
}

df = pd.DataFrame(data)

# %%
plt.scatter(df['Tekanan_Darah'], df['Berat_Badan'])
plt.title('Diagram Sebaran Data Tekanan Darah vs Berat Badan')
plt.xlabel('Tekanan Darah')
plt.ylabel('Berat Badan')
plt.show()

# %%
km = KMeans(n_clusters=2)
y_predicted = km.fit_predict(df[['Tekanan_Darah', 'Berat_Badan']])
df['cluster'] = y_predicted
df.head()
# Out:
#       Nama  Tekanan_Darah  Berat_Badan  cluster
# 0     Aida            129           60        0
# 1    Arief            115           58        0
# 2      Adi            122           57        0
# 3  Jasmine            142           80        1
# 4    Laela            148           75        1

# %%
plt.hist(df['cluster'])
plt.title('Histogram Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Data')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Hasil Clustering K-Means Tekanan Darah dan Berat Badan')
plt.xlabel('Tekanan Darah')
plt.ylabel('Berat Badan')

df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]

plt.scatter(df1['Tekanan_Darah'], df1['Berat_Badan'], color='green', label='Cluster 0')
plt.scatter(df2['Tekanan_Darah'], df2['Berat_Badan'], color='red', label='Cluster 1')

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color='purple', marker='*', s=200, label='Centroid')

plt.legend()
plt.show()
